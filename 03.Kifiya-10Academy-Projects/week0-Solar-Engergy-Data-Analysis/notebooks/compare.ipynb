# %%
# 🧩 Section 1: Imports and Setup

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown as md
sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
features = ['GHI', 'DNI', 'DHI', 'TModA', 'TModB', 'Tamb']

# %%
# 🗂️ Section 2: Load and Tag Datasets

# Load cleaned CSVs
benin = pd.read_csv('./data/benin-malanville_cleaned.csv')
sierraleone = pd.read_csv('./data/sierraleone-bumbuna_cleaned.csv')
togo = pd.read_csv('./data/togo-dapaong_qc_cleaned.csv')

# Add country labels
benin['Country'] = 'Benin-Malanville'
sierraleone['Country'] = 'SierraLeone-Bumbuna'
togo['Country'] = 'Togo-Dapaong'

# Combine all
df = pd.concat([benin, sierraleone, togo], ignore_index=True)
df.head()
# Out:
#              Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-08-09 00:01:00  NaN  NaN  NaN   0.0   0.0  26.2  93.4  0.0     0.4
# 1  2021-08-09 00:02:00  NaN  NaN  NaN   0.0   0.0  26.2  93.6  0.0     0.0
# 2  2021-08-09 00:03:00  NaN  NaN  NaN   0.0   0.0  26.2  93.7  0.3     1.1
# 3  2021-08-09 00:04:00  NaN  NaN  NaN   0.0   0.0  26.2  93.3  0.2     0.7
# 4  2021-08-09 00:05:00  NaN  NaN  NaN   0.0   0.0  26.2  93.3  0.1     0.7
#
#    WSstdev     WD  WDstdev     BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.1  122.1      0.0  998.0       0.0            0.0   26.3   26.2
# 1      0.0    0.0      0.0  998.0       0.0            0.0   26.3   26.2
# 2      0.5  124.6      1.5  997.0       0.0            0.0   26.4   26.2
# 3      0.4  120.3      1.3  997.0       0.0            0.0   26.4   26.3
# 4      0.3  113.2      1.0  997.0       0.0            0.0   26.4   26.3
#
#    Comments           Country
# 0       NaN  Benin-Malanville
# ...

# %%
# 📊 Section 3: Summary Statistics by Country

summary = df.groupby('Country')[features].describe().round(2)
summary
# Out:
#                           GHI                                                  \
#                         count    mean     std  min  25%   50%     75%     max
# Country
# Benin-Malanville     525209.0  242.27  330.06  0.0  0.2  2.50  483.80  1413.0
# SierraLeone-Bumbuna   11530.0  221.55  318.17  0.0  0.1  0.25  415.78  1184.0
# Togo-Dapaong         188338.0  245.79  329.98  0.0  0.3  0.90  529.48  1139.0
#
#                           DNI          ... TModB            Tamb               \
#                         count    mean  ...   75%   max     count   mean   std
# Country                                ...
# Benin-Malanville     525471.0  167.56  ...  41.5  72.5  525600.0  28.18  5.92
# SierraLeone-Bumbuna   11922.0  139.91  ...  44.0  66.7   11925.0  25.42  3.39
# Togo-Dapaong         188680.0  213.34  ...  43.2  76.1  188680.0  27.32  5.46
#
#
#                       min   25%   50%   75%   max
# Country
# Benin-Malanville     11.0  24.2  28.0  32.3  43.8
# ...

# %%
# 📦 Section 4: Boxplots of Each Feature by Country

def boxplot_feature(feature):
    plt.figure()
    sns.boxplot(x='Country', y=feature, data=df, palette="Set2")
    plt.title(f'{feature} Distribution by Country')
    plt.xticks(rotation=15)
    plt.tight_layout()
    plt.show()

# Loop over relevant features
for feat in features:
    boxplot_feature(feat)
# Out:
# <ipython-input-7-4745e2f3992e>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Country', y=feature, data=df, palette="Set2")
# <ipython-input-7-4745e2f3992e>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Country', y=feature, data=df, palette="Set2")
# <ipython-input-7-4745e2f3992e>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Country', y=feature, data=df, palette="Set2")
# <ipython-input-7-4745e2f3992e>:5: FutureWarning:
#
# ...

# %%
# 🔁 Section 5: Correlation Heatmap for Each Country

for country, data in df.groupby('Country'):
    plt.figure(figsize=(8, 6))
    sns.heatmap(data[features].corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
    plt.title(f'Correlation Matrix - {country}')
    plt.tight_layout()
    plt.show()
